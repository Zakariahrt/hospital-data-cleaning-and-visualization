# %%
import pandas as pd

# %%
# %run function.py

# %% [markdown]
# Import Content

# %%
df=display()
df

# %% [markdown]
# CLEANING DATA ENCOUNTER

# %%
path ='C:\Users\Desktop\Hospital_project\encounters.csv'
encounter_df=load_csv(path)

# %%
display_description(encounter_df)
# Out:
# DataFrame Description:
#                CODE  BASE_ENCOUNTER_COST  PAYER_COVERAGE    REASONCODE
# count  2.789100e+04         27891.000000    27891.000000  8.350000e+03
# mean   2.972670e+08           116.181614     1114.965652  4.750331e+11
# std    2.017839e+08            28.410082     4768.615576  5.871996e+12
# min    1.505002e+06            85.550000        0.000000  5.602001e+06
# 25%    1.853450e+08            85.550000        0.000000  5.582200e+07
# 50%    1.853490e+08           136.800000       28.440000  8.880501e+07
# 75%    4.244410e+08           142.580000      155.770000  1.956620e+08
# max    7.029270e+08           146.180000   247751.420000  1.240000e+14

# %%
duplicated_encounter='C:\Users\Desktop\Hospital_project\duplica.csv'
handle_duplicates(encounter_df,duplicated_encounter)
# Out:
# No duplicate rows found.
#                                          Id                 START  \
# 0      32c84703-2481-49cd-d571-3899d5820253  2011|01|02T09:26:36Z
# 1      c98059da-320a-c0a6-fced-c8815f3e3f39  2011|01|03T05:44:39Z
# 2      4ad28a3a-2479-782b-f29c-d5b3f41a001e  2011|01|03T14:32:11Z
# 3      c3f4da61-e4b4-21d5-587a-fbc89943bc19  2011|01|03T16:24:45Z
# 4      a9183b4f-2572-72ea-54c2-b3cd038b4be7  2011|01|03T17:36:53Z
# ...                                     ...                   ...
# 27886  917bb534-2ed3-e1f5-ac27-74f314d19c63  2022|01|29T11:42:06Z
# 27887  07710480-9d6b-9c9b-87c3-c1d54df4069d  2022|01|29T20:12:53Z
# 27888  01b57f06-cebe-a3e4-4423-a796ffb0c35d  2022|01|29T20:35:37Z
# 27889  7d435668-0813-eb3b-0f26-cb741fb39561  2022|01|29T20:35:37Z
# 27890  64dfd3ce-7123-fa23-ec24-f74b492553e2  2022|02|05T20:27:36Z
#
#                        STOP                               PATIENT  \
# 0      2011-01-02T12:58:36Z  3de74169-7f67-9304-91d4-757e0f3a14d2
# ...

# %%
missing_value(encounter_df)
# Out:
# Id                         0
# START                      0
# STOP                       0
# PATIENT                    0
# ORGANIZATION               0
# PAYER                      0
# ENCOUNTERCLASS             0
# CODE                       0
# DESCRIPTION                0
# BASE_ENCOUNTER_COST        0
# TOTAL_CLAIM_COST           0
# PAYER_COVERAGE             0
# REASONCODE             19541
# REASONDESCRIPTION      19541
# dtype: int64

# %%
new_encounter=clean_dates(encounter_df,encounter_df['START'])
new_encounter=clean_dates(encounter_df,encounter_df['STOP'])

# %%
path2='C:\Users\Desktop\Hospital_project\clean_encounter.csv'
save_csv(new_encounter,path2)

# %% [markdown]
# PATIENTS CLEANING

# %%
path3='C:\Users\Desktop\Hospital_project\patients.csv'
patients_df=load_csv(path3,delimiter=':',encoding='latin-1')

# %%
path4='C:\Users\Desktop\Hospital_project\duplicated.csv'
handle_duplicates(patients_df,path4)
# Out:
# Removed 20 duplicate rows. Duplicates saved to C:/Users/User/Downloads/Data Analytics Project/Dataset/work_flow/dup2.csv.
#                                        Id   BIRTHDATE   DEATHDATE PREFIX  \
# 0    5605b66b-e92d-c16c-1b83-b8bf7040d51f  1977|03-19         NaN   Mrs.
# 1    6e5ae27c-8038-7988-e2c0-25a103f01bfa  1940|02-19         NaN    Mr.
# 2    8123d076-0886-9007-e956-d5864aa121a7  1958|06-04         NaN    Mr.
# 3    770518e4-6133-648e-60c9-071eb2f0e2ce  1928|12-25  2017-09-29    Mr.
# 4    f96addf5-81b9-0aab-7855-d208d3d352c5  1928|12-25  2014-02-23    Mr.
# ..                                    ...         ...         ...    ...
# 969  d684571e-a784-ef61-429e-06fa0d2b1637  1924|03-15         NaN    Mr.
# 970  13c6f26e-17b7-f534-04db-78a26b26018d  1940|10-31         NaN   Mrs.
# 971  521e998b-ff0e-767f-b0ee-2bdf1168d66c  1943|04-18         NaN    Mr.
# 972  b57e24a2-2e48-12f9-3293-c88745cfdc3f  1941|04-28         NaN   Mrs.
# ...

# %%
missing_value(patients_df)
# Out:
# Id              0
# BIRTHDATE       0
# DEATHDATE     840
# PREFIX          0
# FIRST           0
# LAST            0
# SUFFIX        973
# MAIDEN        600
# MARITAL         1
# RACE            0
# ETHNICITY       0
# GENDER        487
# BIRTHPLACE      0
# ADDRESS         0
# CITY            0
# STATE           0
# COUNTY          0
# ZIP           145
# LAT             0
# LON             0
# dtype: int64

# %%
new_patients=fillna_with_prefix(patients_df)

# %%
new_patients=clean_dates(patients_df,patients_df['BIRTHDATE'])
new_patients=clean_dates(patients_df,patients_df['DEATHDATE'])

# %%
path5='C:\Users\Desktop\Hospital_project\clean_patients.csv'
save_csv(new_patients,path5)

# %%
path7= 'C:\Users\Desktop\Hospital_project\data_dictionary.csv'
df_dic=load_csv(path7)

# %%
display_head(df_dic)
# Out:
# DataFrame Head:
#         Table    Field                                        Description
# 0  encounters      NaN                             Patient encounter data
# 1  encounters       Id   Primary Key. Unique Identifier of the encounter.
# 2  encounters    Start  The date and time (iso8601 UTC Date (yyyy-MM-d...
# 3  encounters     Stop  The date and time (iso8601 UTC Date (yyyy-MM-d...
# 4  encounters  Patient                        Foreign key to the Patient.
